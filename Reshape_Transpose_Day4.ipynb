# %% [markdown]
# <a href="https://colab.research.google.com/github/mmugilamugila-art/Data-Analytics-using-python-project-/blob/main/Reshape_Transpose_Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr = np.array([1,2,3,4,5,6])
new_arr = arr.reshape(2,3)
print(new_arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# Aggregation func

# %%
import numpy as np
marks = np.array([48,60,80,78,92])
average = np.mean(marks)
print(average)
# Out:
# 71.6

# %%
import numpy as np
marks = np.array([50,90,84,78,92])
average = np.median(marks)
print(average)
# Out:
# 84.0
