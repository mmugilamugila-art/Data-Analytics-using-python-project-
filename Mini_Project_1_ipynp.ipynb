# %% [markdown]
# <a href="https://colab.research.google.com/github/mmugilamugila-art/Data-Analytics-using-python-project-/blob/main/Mini_Project_1_ipynp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
data = {
    "order_id": ["OD1001", "OD1002", "OD1003", "OD1004", "OD1005", "OD1006", "OD1007", "OD1008", "OD1009", "OD1010", "OD1011", "OD1012", "OD1013", "OD1014", "OD1015", "OD1016", "OD1017", "OD1018", "OD1019", "OD1020"],
    "order_date": ["2025-01-05", "2025-01-07", "2025-01-12", "2025-01-15", "2025-01-18", "2025-02-02", "2025-02-10", "2025-02-14", "2025-02-20", "2025-03-01", "2025-03-05", "2025-03-12", "2025-03-18", "2025-04-02", "2025-04-09", "2025-04-15", "2025-04-22", "2025-05-04", "2025-05-11", "2025-05-25"],
    "product_name": ["iPhone 15", "Running Shoes", "Coffee Maker", "Gaming Chair", "Bluetooth Speaker", "Leather Wallet", "Air Fryer", "Study Desk", "MacBook Air", "Winter Jacket", "Vacuum Cleaner", "Dining Table", "Wireless Mouse", "Yoga Mat", "Microwave Oven", "Office Chair", "Smart Watch", "Sneakers", "Blender", "Bookshelf"],
    "category": ["Electronics", "Apparel", "Home Appliances", "Furniture", "Electronics", "Apparel", "Home Appliances", "Furniture", "Electronics", "Apparel", "Home Appliances", "Furniture", "Electronics", "Apparel", "Home Appliances", "Furniture", "Electronics", "Apparel", "Home Appliances", "Furniture"],
    "quantity_ordered": [1, 2, 1, 1, 3, 5, 1, 1, 1, 2, 1, 1, 10, 4, 1, 2, 2, 1, 2, 1],
    "unit_price": [800, 75, 120, 250, 50, 30, 150, 180, 1000, 110, 200, 450, 20, 25, 170, 120, 150, 90, 60, 130],
    "total_amount": [800, 150, 120, 250, 150, 150, 150, 180, 1000, 220, 200, 450, 200, 100, 170, 240, 300, 90, 120, 130],
    "region": ["North", "South", "East", "West", "North", "South", "West", "East", "North", "South", "West", "East", "North", "South", "West", "East", "North", "South", "West", "East"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    order_id  order_date       product_name         category  quantity_ordered  \
# 0    OD1001  2025-01-05          iPhone 15      Electronics                 1
# 1    OD1002  2025-01-07      Running Shoes          Apparel                 2
# 2    OD1003  2025-01-12       Coffee Maker  Home Appliances                 1
# 3    OD1004  2025-01-15       Gaming Chair        Furniture                 1
# 4    OD1005  2025-01-18  Bluetooth Speaker      Electronics                 3
# 5    OD1006  2025-02-02     Leather Wallet          Apparel                 5
# 6    OD1007  2025-02-10          Air Fryer  Home Appliances                 1
# 7    OD1008  2025-02-14         Study Desk        Furniture                 1
# 8    OD1009  2025-02-20        MacBook Air      Electronics                 1
# 9    OD1010  2025-03-01      Winter Jacket          Apparel                 2
# 10   OD1011  2025-03-05     Vacuum Cleaner  Home Appliances                 1
# ...

# %%
df.head(20)
# Out:
#    order_id  order_date       product_name         category  quantity_ordered  \
# 0    OD1001  2025-01-05          iPhone 15      Electronics                 1
# 1    OD1002  2025-01-07      Running Shoes          Apparel                 2
# 2    OD1003  2025-01-12       Coffee Maker  Home Appliances                 1
# 3    OD1004  2025-01-15       Gaming Chair        Furniture                 1
# 4    OD1005  2025-01-18  Bluetooth Speaker      Electronics                 3
# 5    OD1006  2025-02-02     Leather Wallet          Apparel                 5
# 6    OD1007  2025-02-10          Air Fryer  Home Appliances                 1
# 7    OD1008  2025-02-14         Study Desk        Furniture                 1
# 8    OD1009  2025-02-20        MacBook Air      Electronics                 1
# 9    OD1010  2025-03-01      Winter Jacket          Apparel                 2
# 10   OD1011  2025-03-05     Vacuum Cleaner  Home Appliances                 1
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          20 non-null     object
#  1   order_date        20 non-null     object
#  2   product_name      20 non-null     object
#  3   category          20 non-null     object
#  4   quantity_ordered  20 non-null     int64
#  5   unit_price        20 non-null     int64
#  6   total_amount      20 non-null     int64
#  7   region            20 non-null     object
# dtypes: int64(3), object(5)
# memory usage: 1.4+ KB
# None

# %%
print(df.shape)
# Out:
# (20, 8)

# %%
print(df.isnull().sum())
# Out:
# order_id            0
# order_date          0
# product_name        0
# category            0
# quantity_ordered    0
# unit_price          0
# total_amount        0
# region              0
# dtype: int64

# %%
df = df.drop_duplicates()
print(df)
# Out:
#    order_id  order_date       product_name         category  quantity_ordered  \
# 0    OD1001  2025-01-05          iPhone 15      Electronics                 1
# 1    OD1002  2025-01-07      Running Shoes          Apparel                 2
# 2    OD1003  2025-01-12       Coffee Maker  Home Appliances                 1
# 3    OD1004  2025-01-15       Gaming Chair        Furniture                 1
# 4    OD1005  2025-01-18  Bluetooth Speaker      Electronics                 3
# 5    OD1006  2025-02-02     Leather Wallet          Apparel                 5
# 6    OD1007  2025-02-10          Air Fryer  Home Appliances                 1
# 7    OD1008  2025-02-14         Study Desk        Furniture                 1
# 8    OD1009  2025-02-20        MacBook Air      Electronics                 1
# 9    OD1010  2025-03-01      Winter Jacket          Apparel                 2
# 10   OD1011  2025-03-05     Vacuum Cleaner  Home Appliances                 1
# ...

# %%
total_sales = df["total_amount"].sum()
print("Total Sales:",total_sales)
# Out:
# Total Sales: 5170

# %%
product_sales = df.groupby("product_name")["total_amount"].sum()
print(product_sales)
# Out:
# product_name
# Air Fryer             150
# Blender               120
# Bluetooth Speaker     150
# Bookshelf             130
# Coffee Maker          120
# Dining Table          450
# Gaming Chair          250
# Leather Wallet        150
# MacBook Air          1000
# Microwave Oven        170
# Office Chair          240
# Running Shoes         150
# Smart Watch           300
# Sneakers               90
# Study Desk            180
# Vacuum Cleaner        200
# Winter Jacket         220
# Wireless Mouse        200
# Yoga Mat              100
# iPhone 15             800
# Name: total_amount, dtype: int64

# %%
product_sales.plot(kind = 'bar')
plt.title("Product Sales Analysis")
plt.xlabel("Product Name")
plt.ylabel("Sales")
plt.show()
