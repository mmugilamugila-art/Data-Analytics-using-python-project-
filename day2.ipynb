# %% [markdown]
# <a href="https://colab.research.google.com/github/mmugilamugila-art/Data-Analytics-using-python-project-/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Simple Function

# %%
def greet():

  print("Hi Internship Students")
greet()
# Out:
# Hi Internship Students

# %%
def greet_name(name):

  print("Welcome", name)
greet_name("Ram")
# Out:
# Welcome Ram

# %%
def add(a, b):

  return a + b

result = add(10, 40)
print("Sum=", result)
# Out:
# Sum= 50

# %% [markdown]
# Error handling

# %%
try:
  num=int(input("Enter Number:"))
  print(num)
except:
  print("Invalid Input")
# Out:
# Enter Number:623
# 623
